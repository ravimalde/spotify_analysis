# %%
import json
import pandas as pd
from GetLyrics import GetLyrics
from nltk.corpus import stopwords
from nltk.tokenize import RegexpTokenizer

# %%
def get_keys(path):
    with open(path) as f:
        return json.load(f)

# %%
keys = get_keys("/Users/ravimalde/.secret/spotify_genius.json")
spotify_client_id = keys['spotify_client_id']
spotify_client_secret = keys["spotify_client_secret"]
genius_key = keys["genius_key"]
user_id = "spotify:user:1144576376"
playlist_id = "spotify:playlist:37i9dQZF1EtsoRWQYQkq7l"

# %%
songs = GetLyrics(spotify_client_id, spotify_client_secret, user_id, playlist_id, genius_key)
song_lyrics = songs.get_lyrics()
# Out:
# Working on track 0.
# Retrieved track 0 lyrics!
#
#
# Working on track 1.
# Retrieved track 1 lyrics!
#
#
# Working on track 2.
# Retrieved track 2 lyrics!
#
#
# Working on track 3.
# Track 3 is not in the Genius database.
#
#
# Working on track 4.
# Retrieved track 4 lyrics!
#
#
# Working on track 5.
# Retrieved track 5 lyrics!
#
#
# Working on track 6.
# Retrieved track 6 lyrics!
#
#
# Working on track 7.
# Retrieved track 7 lyrics!
#
#
# Working on track 8.
# Retrieved track 8 lyrics!
#
#
# Working on track 9.
# Retrieved track 9 lyrics!
#
#
# Working on track 10.
# Track 10 is not in the Genius database.
#
#
# Working on track 11.
# Track 11 is not in the Genius database.
#
#
# Working on track 12.
# Retrieved track 12 lyrics!
#
#
# Working on track 13.
# Retrieved track 13 lyrics!
#
#
# Working on track 14.
# Retrieved track 14 lyrics!
#
#
# Working on track 15.
# Track 15 is not in the Genius database.
#
#
# Working on track 16.
# Retrieved track 16 lyrics!
#
#
# Working on track 17.
# Retrieved track 17 lyrics!
#
#
# Working on track 18.
# Track 18 is not in the Genius database.
#
#
# Working on track 19.
# Track 19 is not in the Genius database.
#
#
# Working on track 20.
# Track 20 is not in the Genius database.
#
#
# Working on track 21.
# Track 21 is not in the Genius database.
#
#
# Working on track 22.
# Retrieved track 22 lyrics!
#
#
# Working on track 23.
# Track 23 is not in the Genius database.
#
#
# Working on track 24.
# Track 24 is not in the Genius database.
#
#
# Working on track 25.
# Retrieved track 25 lyrics!
#
#
# Working on track 26.
# Retrieved track 26 lyrics!
#
#
# Working on track 27.
# Retrieved track 27 lyrics!
#
#
# Working on track 28.
# Retrieved track 28 lyrics!
#
#
# Working on track 29.
# Track 29 is not in the Genius database.
#
#
# Working on track 30.
# Retrieved track 30 lyrics!
#
#
# Working on track 31.
# Retrieved track 31 lyrics!
#
#
# Working on track 32.
# Track 32 is not in the Genius database.
#
#
# Working on track 33.
# Retrieved track 33 lyrics!
#
#
# Working on track 34.
# Retrieved track 34 lyrics!
#
#
# Working on track 35.
# Track 35 is not in the Genius database.
#
#
# Working on track 36.
# Retrieved track 36 lyrics!
#
#
# Working on track 37.
# Retrieved track 37 lyrics!
#
#
# Working on track 38.
# Retrieved track 38 lyrics!
#
#
# Working on track 39.
# Retrieved track 39 lyrics!
#
#
# Working on track 40.
# Retrieved track 40 lyrics!
#
#
# Working on track 41.
# Retrieved track 41 lyrics!
#
#
# Working on track 42.
# Retrieved track 42 lyrics!
#
#
# Working on track 43.
# Retrieved track 43 lyrics!
#
#
# Working on track 44.
# Retrieved track 44 lyrics!
#
#
# Working on track 45.
# Retrieved track 45 lyrics!
#
#
# Working on track 46.
# Retrieved track 46 lyrics!
#
#
# Working on track 47.
# Track 47 is not in the Genius database.
#
#
# Working on track 48.
# Retrieved track 48 lyrics!
#
#
# Working on track 49.
# Retrieved track 49 lyrics!
#
#
# Working on track 50.
# Track 50 is not in the Genius database.
#
#
# Working on track 51.
# Retrieved track 51 lyrics!
#
#
# Working on track 52.
# Track 52 is not in the Genius database.
#
#
# Working on track 53.
# Retrieved track 53 lyrics!
#
#
# Working on track 54.
# Track 54 is not in the Genius database.
#
#
# Working on track 55.
# Retrieved track 55 lyrics!
#
#
# Working on track 56.
# Retrieved track 56 lyrics!
#
#
# Working on track 57.
# Track 57 is not in the Genius database.
#
#
# Working on track 58.
# Track 58 is not in the Genius database.
#
#
# Working on track 59.
# Track 59 is not in the Genius database.
#
#
# Working on track 60.
# Track 60 is not in the Genius database.
#
#
# Working on track 61.
# Retrieved track 61 lyrics!
#
#
# Working on track 62.
# Retrieved track 62 lyrics!
#
#
# Working on track 63.
# Retrieved track 63 lyrics!
#
#
# Working on track 64.
# Retrieved track 64 lyrics!
#
#
# Working on track 65.
# Track 65 is not in the Genius database.
#
#
# Working on track 66.
# Track 66 is not in the Genius database.
#
#
# Working on track 67.
# Retrieved track 67 lyrics!
#
#
# Working on track 68.
# Track 68 is not in the Genius database.
#
#
# Working on track 69.
# Retrieved track 69 lyrics!
#
#
# Working on track 70.
# Retrieved track 70 lyrics!
#
#
# Working on track 71.
# Track 71 is not in the Genius database.
#
#
# Working on track 72.
# Track 72 is not in the Genius database.
#
#
# Working on track 73.
# Track 73 is not in the Genius database.
#
#
# Working on track 74.
# Retrieved track 74 lyrics!
#
#
# Working on track 75.
# Retrieved track 75 lyrics!
#
#
# Working on track 76.
# Retrieved track 76 lyrics!
#
#
# Working on track 77.
# Retrieved track 77 lyrics!
#
#
# Working on track 78.
# Retrieved track 78 lyrics!
#
#
# Working on track 79.
# Retrieved track 79 lyrics!
#
#
# Working on track 80.
# Retrieved track 80 lyrics!
#
#
# Working on track 81.
# Track 81 is not in the Genius database.
#
#
# Working on track 82.
# Retrieved track 82 lyrics!
#
#
# Working on track 83.
# Retrieved track 83 lyrics!
#
#
# Working on track 84.
# Track 84 is not in the Genius database.
#
#
# Working on track 85.
# Track 85 is not in the Genius database.
#
#
# Working on track 86.
# Retrieved track 86 lyrics!
#
#
# Working on track 87.
# Retrieved track 87 lyrics!
#
#
# Working on track 88.
# Track 88 is not in the Genius database.
#
#
# Working on track 89.
# Retrieved track 89 lyrics!
#
#
# Working on track 90.
# Retrieved track 90 lyrics!
#
#
# Working on track 91.
# Retrieved track 91 lyrics!
#
#
# Working on track 92.
# Retrieved track 92 lyrics!
#
#
# Working on track 93.
# Track 93 is not in the Genius database.
#
#
# Working on track 94.
# Retrieved track 94 lyrics!
#
#
# Working on track 95.
# Retrieved track 95 lyrics!
#
#
# Working on track 96.
# Track 96 is not in the Genius database.
#
#
# Working on track 97.
# Retrieved track 97 lyrics!
#
#
# Working on track 98.
# Retrieved track 98 lyrics!
#
#
# Working on track 99.
# Retrieved track 99 lyrics!

# %%
df = pd.DataFrame()
df['track_name'] = songs.track_names
df['artist'] = songs.track_artists
df['lyrics'] = song_lyrics

# %%
df.to_csv("lyrics.csv")

# %%
df
# Out:
#                                  track_name         artist  \
# 0                            Problems In Us      Col3trane
# 1                                New Shapes          Diplo
# 2                                 Throwaway       SG Lewis
# 3                                 Electrian    DJ Seinfeld
# 4                                      Skip     SuperParka
# ..                                      ...            ...
# 95                                   Softly         Clairo
# 96             Club Paradise - Zodivk Remix      Savy Soul
# 97  Pumpy (feat. AJ x Deno, Swarmz & Cadet)  Da Beatfreakz
# 98                                Nevermind   Dennis Lloyd
# 99                                   Linked         Bonobo
#
#                                                lyrics
# 0   [Pre-Chorus]I couldn't believe that you would ...
# 1   [Chorus]You don't show me no sign of your inno...
# 2   \n\n[Verse 1]\nSometimes I know what's right f...
# 3                                                None
# 4   \n\nI will not always be your friend\nTell you...
# ..                                                ...
# 95  \n\n[Verse 1]\nIs it alright to feel this way ...
# 96                                               None
# 97  [Intro: Swarmz & Cadet]This is the 9 sideCADET...
# 98  [Intro]What if I left and it made no senseAnd ...
# 99                               [Non-Lyrical Vocals]
#
# [100 rows x 3 columns]
